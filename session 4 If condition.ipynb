# %%
a=["apple","Banana"]
print("pineapple" not in a)
# Out:
# True

# %%
num=11
if (num%2 == 0):
    print("Number is even")
else:
    print("Number is odd")
# Out:
# Number is odd

# %%
num=int(input("Enter number"))
if num > 0:
    print("positive number")
elif(num%2 == 0):
    print("Number is even")
 
else:
    print("-Ve ")
# Out:
# Enter number-15
# -Ve

# %%
num=int(input("Enter number"))
if num > 0:
    print("positive number")
if(num%2 == 0):
    print("Number is even")
if(num < 0):
    print("Number is -ve")
if(num%2 != 0):
    print("Number is odd")
# Out:
# Enter number-9
# Number is -ve
# Number is odd

# %%
60-70= C
70-80= B
80-90 =A
90-100=A+

# %%
num=int(input("Enter number"))# user define input
print(num)
# Out:
# Enter number12
# 12

# %%
if num >0:
  print("Number is +ve")
# Out:
# Number is +ve

# %%
num=int(input("Enter number"))
if num >0:
  print("Number is +ve")
else:
    print("Number is -Ve")
# Out:
# Enter number-8
# Number is -Ve

# %%
num=int(input("Enter number"))
if num >0:
  print("Number is +ve")
elif num >10:
  print("Number is greate thn 10")
else:
    print("Number is -Ve")
# Out:
# Enter number12
# Number is +ve

# %%
num=int(input("Enter number"))
if num >0:
  print("Number is +ve")
if num >10:
  print("Number is greate thn 10")
else:
    print("Number is -Ve")
# Out:
# Enter number12
# Number is +ve
# Number is greate thn 10

# %%
num=int(input("Enter number"))
if num >0:
  print("Number is +ve")
  if num >10:
     print("Number is greate thn 10")
else:
    print("Number is -Ve")
# Out:
# Enter number12
# Number is +ve
# Number is greate thn 10
